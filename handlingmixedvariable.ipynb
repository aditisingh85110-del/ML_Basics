# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Ticket'].unique()
# Out:
# array(['330911', '363272', '240276', '315154', '3101298', '7538',
#        '330972', '248738', '2657', 'A/4 48871', '349220', '694', '21228',
#        '24065', 'W.E.P. 5734', 'SC/PARIS 2167', '233734', '2692',
#        'STON/O2. 3101270', '2696', 'PC 17603', 'C 17368', 'PC 17598',
#        'PC 17597', 'PC 17608', 'A/5. 3337', '113509', '2698', '113054',
#        '2662', 'SC/AH 3085', 'C.A. 31029', 'C.A. 2315', 'W./C. 6607',
#        '13236', '2682', '342712', '315087', '345768', '1601', '349256',
#        '113778', 'SOTON/O.Q. 3101263', '237249', '11753',
#        'STON/O 2. 3101291', 'PC 17594', '370374', '11813', 'C.A. 37671',
#        '13695', 'SC/PARIS 2168', '29105', '19950', 'SC/A.3 2861',
#        '382652', '349230', '348122', '386525', '349232', '237216',
#        '347090', '334914', 'F.C.C. 13534', '330963', '113796', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '113503', '359306',
#        '11770', '248744', '368702', '2678', 'PC 17483', '19924', '349238',
#        '240261', '2660', '330844', 'A/4 31416', '364856', '29103',
#        '347072', '345498', 'F.C. 12750', '376563', '13905', '350033',
#        '19877', 'STON/O 2. 3101268', '347471', 'A./5. 3338', '11778',
#        '228414', '365235', '347070', '2625', 'C 4001', '330920', '383162',
#        '3410', '248734', '237734', '330968', 'PC 17531', '329944', '2680',
#        '2681', 'PP 9549', '13050', 'SC/AH 29037', 'C.A. 33595', '367227',
#        '392095', '368783', '371362', '350045', '367226', '211535',
#        '342441', 'STON/OQ. 369943', '113780', '4133', '2621', '349226',
#        '350409', '2656', '248659', 'SOTON/OQ 392083', 'CA 2144', '113781',
#        '244358', '17475', '345763', '17463', 'SC/A4 23568', '113791',
#        '250651', '11767', '349255', '3701', '350405', '347077',
#        'S.O./P.P. 752', '347469', '110489', 'SOTON/O.Q. 3101315',
#        '335432', '2650', '220844', '343271', '237393', '315153',
#        'PC 17591', 'W./C. 6608', '17770', '7548', 'S.O./P.P. 251', '2670',
#        '2673', '29750', 'C.A. 33112', '230136', 'PC 17756', '233478',
#        '113773', '7935', 'PC 17558', '239059', 'S.O./P.P. 2', 'A/4 48873',
#        'CA. 2343', '28221', '226875', '111163', 'A/5. 851', '235509',
#        '28220', '347465', '16966', '347066', 'C.A. 31030', '65305',
#        '36568', '347080', 'PC 17757', '26360', 'C.A. 34050', 'F.C. 12998',
#        '9232', '28034', 'PC 17613', '349250', 'SOTON/O.Q. 3101308',
#        'S.O.C. 14879', '347091', '113038', '330924', '36928', '32302',
#        'SC/PARIS 2148', '342684', 'W./C. 14266', '350053', 'PC 17606',
#        '2661', '350054', '370368', 'C.A. 6212', '242963', '220845',
#        '113795', '3101266', '330971', 'PC 17599', '350416', '110813',
#        '2679', '250650', 'PC 17761', '112377', '237789', '3470', '17464',
#        '26707', 'C.A. 34651', 'SOTON/O2 3101284', '13508', '7266',
#        '345775', 'C.A. 42795', 'AQ/4 3130', '363611', '28404', '345501',
#        '345572', '350410', 'C.A. 34644', '349235', '112051', 'C.A. 49867',
#        'A. 2. 39186', '315095', '368573', '370371', '2676', '236853',
#        'SC 14888', '2926', 'CA 31352', 'W./C. 14260', '315085', '364859',
#        '370129', 'A/5 21175', 'SOTON/O.Q. 3101314', '2655', 'A/5 1478',
#        'PC 17607', '382650', '2652', '33638', '345771', '349202',
#        'SC/Paris 2123', '113801', '347467', '347079', '237735', '315092',
#        '383123', '112901', '392091', '12749', '350026', '315091', '2658',
#        'LP 1588', '368364', 'PC 17760', 'AQ/3. 30631', 'PC 17569',
#        '28004', '350408', '347075', '2654', '244368', '113790', '24160',
#        'SOTON/O.Q. 3101309', 'PC 17585', '2003', '236854', 'PC 17580',
#        '2684', '2653', '349229', '110469', '244360', '2675', '2622',
#        'C.A. 15185', '350403', 'PC 17755', '348125', '237670', '2688',
#        '248726', 'F.C.C. 13528', 'PC 17759', 'F.C.C. 13540', '113044',
#        '11769', '1222', '368402', '349910', 'S.C./PARIS 2079', '315083',
#        '11765', '2689', '3101295', '112378', 'SC/PARIS 2147', '28133',
#        '112058', '248746', '315152', '29107', '680', '366713', '330910',
#        '364498', '376566', 'SC/PARIS 2159', '349911', '244346', '364858',
#        '349909', 'PC 17592', 'C.A. 2673', 'C.A. 30769', '371109', '13567',
#        '347065', '21332', '28664', '113059', '17765', 'SC/PARIS 2166',
#        '28666', '334915', '365237', '19928', '347086', 'A.5. 3236',
#        'PC 17758', 'SOTON/O.Q. 3101262', '359309', '2668'], dtype=object)

# %%
fig = df['Ticket'].value_counts().plot.bar()
fig.set_title('Passengers travelling with')

# %%
# extract numerical part
df['ticket_numerical'] = pd.to_numeric(df["Ticket"],errors='coerce',downcast='integer')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked  ticket_numerical cabin_num cabin_cat  \
# 0   330911   7.8292   NaN        Q          330911.0       NaN       NaN
# 1   363272   7.0000   NaN        S          363272.0       NaN       NaN
# 2   240276   9.6875   NaN        Q          240276.0       NaN       NaN
# 3   315154   8.6625   NaN        S          315154.0       NaN       NaN
# 4  3101298  12.2875   NaN        S         3101298.0       NaN       NaN
#
#    ticket_num ticket_cat
# 0      330911        NaN
# 1      363272        NaN
# 2      240276        NaN
# 3      315154        NaN
# 4     3101298        NaN

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
df['cabin_num'] = df['Cabin'].str.extract('(\d+)') # captures numerical part
df['cabin_cat'] = df['Cabin'].str[0] # captures the first letter

df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 96           988         1       1
# 182         1074         1       1
# 329         1221         0       2
# 169         1061         1       3
# 72           964         1       3
# 365         1257         1       3
# 6            898         1       3
# 190         1082         0       2
# 94           986         0       1
# 297         1189         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 182  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...  female  18.0      1
# 329                                Enander, Mr. Ingvar    male  21.0      0
# 169                       Hellstrom, Miss. Hilda Maria  female  22.0      0
# 72                      Nieminen, Miss. Manta Josefina  female  29.0      0
# 365                     Sage, Mrs. John (Annie Bullen)  female   NaN      1
# 6                                 Connolly, Miss. Kate  female  30.0      0
# 190                               Angle, Mr. William A    male  34.0      1
# 94                                 Birnbaum, Mr. Jakob    male  25.0      0
# 297                                  Samaan, Mr. Hanna    male   NaN      2
#
#      Parch    Ticket     Fare Cabin Embarked  ticket_numerical cabin_num  \
# 96       0     19877  78.8500   C46        S           19877.0        46
# 182      0    113773  53.1000   D30        S          113773.0        30
# 329      0    236854  13.0000   NaN        S          236854.0       NaN
# 169      0      7548   8.9625   NaN        S            7548.0       NaN
# 72       0   3101297   7.9250   NaN        S         3101297.0       NaN
# 365      9  CA. 2343  69.5500   NaN        S               NaN       NaN
# 6        0    330972   7.6292   NaN        Q          330972.0       NaN
# 190      0    226875  26.0000   NaN        S          226875.0       NaN
# 94       0     13905  26.0000   NaN        C           13905.0       NaN
# 297      0      2662  21.6792   NaN        C            2662.0       NaN
#
#     cabin_cat
# 96          C
# 182         D
# 329       NaN
# 169       NaN
# 72        NaN
# 365       NaN
# 6         NaN
# 190       NaN
# 94        NaN
# 297       NaN

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='cabin_cat'>

# %%
# extract the last bit of ticket as number
df['ticket_num'] = df['Ticket'].apply(lambda s: s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],
                                   errors='coerce',
                                   downcast='integer')

# extract the first part of ticket as category
df['ticket_cat'] = df['Ticket'].apply(lambda s: s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan,
                              df['ticket_cat'])

df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 7                        Caldwell, Mr. Albert Francis    male  26.0      1
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                             Davies, Mr. John Samuel    male  21.0      2
# 10                                   Ilieff, Mr. Ylio    male   NaN      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 16                                  Keane, Mr. Daniel    male  35.0      0
# 17                                  Assaf, Mr. Gerios    male  21.0      0
# 18                       Ilmakangas, Miss. Ida Livija  female  27.0      1
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
#
#     Parch            Ticket     Fare Cabin Embarked  ticket_numerical  \
# 0       0            330911   7.8292   NaN        Q          330911.0
# 1       0            363272   7.0000   NaN        S          363272.0
# 2       0            240276   9.6875   NaN        Q          240276.0
# 3       0            315154   8.6625   NaN        S          315154.0
# 4       1           3101298  12.2875   NaN        S         3101298.0
# 5       0              7538   9.2250   NaN        S            7538.0
# 6       0            330972   7.6292   NaN        Q          330972.0
# 7       1            248738  29.0000   NaN        S          248738.0
# 8       0              2657   7.2292   NaN        C            2657.0
# 9       0         A/4 48871  24.1500   NaN        S               NaN
# 10      0            349220   7.8958   NaN        S          349220.0
# 11      0               694  26.0000   NaN        S             694.0
# 12      0             21228  82.2667   B45        S           21228.0
# 13      0             24065  26.0000   NaN        S           24065.0
# 14      0       W.E.P. 5734  61.1750   E31        S               NaN
# 15      0     SC/PARIS 2167  27.7208   NaN        C               NaN
# 16      0            233734  12.3500   NaN        Q          233734.0
# 17      0              2692   7.2250   NaN        C            2692.0
# 18      0  STON/O2. 3101270   7.9250   NaN        S               NaN
# 19      0              2696   7.2250   NaN        C            2696.0
#
#    cabin_num cabin_cat  ticket_num ticket_cat
# 0        NaN       NaN      330911        NaN
# 1        NaN       NaN      363272        NaN
# 2        NaN       NaN      240276        NaN
# 3        NaN       NaN      315154        NaN
# 4        NaN       NaN     3101298        NaN
# 5        NaN       NaN        7538        NaN
# 6        NaN       NaN      330972        NaN
# 7        NaN       NaN      248738        NaN
# 8        NaN       NaN        2657        NaN
# 9        NaN       NaN       48871        A/4
# 10       NaN       NaN      349220        NaN
# 11       NaN       NaN         694        NaN
# 12        45         B       21228        NaN
# 13       NaN       NaN       24065        NaN
# 14        31         E        5734     W.E.P.
# 15       NaN       NaN        2167   SC/PARIS
# 16       NaN       NaN      233734        NaN
# 17       NaN       NaN        2692        NaN
# 18       NaN       NaN     3101270   STON/O2.
# 19       NaN       NaN        2696        NaN

# %%
df['ticket_cat'].unique()
# Out:
# array([nan, 'A/4', 'W.E.P.', 'SC/PARIS', 'STON/O2.', 'PC', 'C', 'A/5.',
#        'SC/AH', 'C.A.', 'W./C.', 'SOTON/O.Q.', 'STON/O', 'SC/A.3',
#        'F.C.C.', 'F.C.', 'A./5.', 'PP', 'STON/OQ.', 'SOTON/OQ', 'CA',
#        'SC/A4', 'S.O./P.P.', 'CA.', 'S.O.C.', 'SOTON/O2', 'AQ/4', 'A.',
#        'SC', 'A/5', 'SC/Paris', 'LP', 'AQ/3.', 'S.C./PARIS', 'A.5.'],
#       dtype=object)
