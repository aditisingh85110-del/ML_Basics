# %%
import pandas as pd
import requests

# %%
url="https://pizza-and-desserts.p.rapidapi.com/pizzas"
headers={
    "x-rapidapi-key": "8abd7c1a66msh431697a773085c0p1f0cebjsn0a32ecf5fc15",
    "x-rapidapi-host": 'pizza-and-desserts.p.rapidapi.com' 

}

response=requests.get(url,headers=headers)
data=response.json()
df=pd.DataFrame(data)
df
# Out:
#     id                             name    veg  price  \
# 0    1                       Margherita   True      3
# 1    2                  Tandoori Paneer   True      7
# 2    3                   Veggie Supreme   True      8
# 3    4            Double Paneer Supreme   True      6
# 4    4            Veggie Kebab Surprise   True      4
# 5    5                  Chicken Supreme  False      7
# 6    6            Chicken Tikka Supreme  False      6
# 7    7             Triple Chicken Feast  False      8
# 8    8                    Chicken Tikka  False      7
# 9    9           Double Chicken Sausage  False      5
# 10  10         Spiced Chicken Meatballs  False      4
# 11  11                    Double Cheese   True      3
# 12  12            Chicken Pepper Crunch  False      5
# 13  13            Italian Chicken Feast  False      6
# 14  14                    Corn & Cheese   True      5
# 15  15                   Tandoori Onion   True      6
# 16  16                Chicken Pepperoni  False      5
# 17  17           Chicken N Corn Delight  False      9
# 18  18                     Farmers Pick   True     29
# 19  19                     Classic Corn   True      5
# 20  20           Classic Onion Capsicum   True      4
# 21  21             Italian Onion Tomato   True      8
# 22  22   Tandoori Mushroom & Sweet Corn   True      5
# 23  23         Schezwan Corn & Capsicum   True      6
# 24  24                      Only Cheesy   True     40
# 25  25                  Classic Sausage  False      8
# 26  26  Classic Paneer Capsicum & Onion   True      6
# 27  27        Italian Pepperoni & Onion  False      5
# 28  28     Schezwan Meatball & Capsicum  False     10
# 29  29           Tandoori Tikka & Onion  False      5
# 30  30   Classic Loaded Chicken Delight  False      9
#
#                                           description  quantity  \
# 0                                              Cheese         1
# 1   Spiced paneeer, Onion,Green Capsicum & Red Pap...         1
# 2   Black Olives,Green Capsicum, Mushroom, Onion,R...         1
# 3   Spiced Paneer, Herbed Onion&Green Capsicum, Re...         1
# 4   Veg Kebab,Onion,Green Capsicum,Tomato & Sweet ...         1
# 5   Herbed Chicken,Schezwan Chicken Meatball,Chick...         1
# 6   Chicken Tikka,Chicken Malai Tikka,Onion,Red Pa...         1
# 7   Schezwan Chicken Meatball Herbed Chicken,Chick...         1
# 8                        Chicken Tikka, Onion, Tomato         1
# 9                                     Chicken Sausage         1
# 10                    Schezwan Chicken Meatball Onion         1
# 11                             Extra Cheese on Cheese         1
# 12  Herbed Chicken, Onion, Green Capsicum, Red Cap...         1
# 13  Herbed Chicken, Onion, Green Capsicum, Red Cap...         1
# 14                                 Cheese ,Sweet Corn         1
# 15                   Cheese & Onion in Tandoori sause         1
# 16                          Cheese ,Chicken pepperoni         1
# 17                          Cheese ,Chicken pepperoni         1
# 18  Onion Herbed & Green Capsicum, Red Capsicum, M...         1
# 19  Pizza topped with our Classic Pan sauce, sweet...         1
# 20  Pizza topped with our Classic Pan sauce, crunc...         1
# 21  Pizza topped with our Chef's Special Italian s...         1
# 22  Pizza topped with our signature tandoori sauce...         1
# 23  Pizza topped with Spicy Schezwan sauce, sweet ...         1
# 24  Pizza topped with cheesy dressing and mozzarel...         1
# 25  Pizza topped with our Classic Pan sauce, flavo...         1
# 26  Pizza topped with our Classic Pan sauce, flavo...         1
# 27  Pizza topped with our Chef's Special Italian s...         1
# 28  Pizza topped with Spicy Schezwan sauce, crunch...         1
# 29  Pizza topped with our signature tandoori sauce...         1
# 30  Pizza topped with our Classic Pan sauce, herbe...         1
#
#                                                   img  \
# 0   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 1   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 2   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 3   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 4   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 5   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 6   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 7   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 8   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 9   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 10  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 11  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 12  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 13  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 14  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 15  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 16  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 17  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 18  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 19  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 20  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 21  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 22  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 23  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 24  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 25  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 26  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 27  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 28  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 29  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 30  https://api.pizzahut.io/v1/content/en-in/in-1/...
#
#                                          sizeandcrust
# 0   [{'mediumPan': [{'price': 3}], 'mediumstuffedc...
# 1   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 2   [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 3   [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 4   [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 5   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 6   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 7   [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 8   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 9   [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 10  [{'mediumPan': [{'price': 4}], 'mediumstuffedc...
# 11  [{'mediumPan': [{'price': 3}], 'mediumstuffedc...
# 12  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 13  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 14  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 15  [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 16  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 17  [{'mediumPan': [{'price': 9}], 'mediumstuffedc...
# 18  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 19  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 20  [{'mediumPan': [{'price': 4}], 'mediumstuffedc...
# 21  [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 22  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 23  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 24  [{'mediumPan': [{'price': 40}], 'mediumstuffed...
# 25  [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 26  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 27  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 28  [{'mediumPan': [{'price': 12}], 'mediumstuffed...
# 29  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 30  [{'mediumPan': [{'price': 9}], 'mediumstuffedc...

# %%
print(response.status_code)
print(response.json())
# Out:
# 200
# {'id': 1, 'name': 'Margherita', 'veg': True, 'price': 3, 'description': 'Cheese', 'quantity': 1, 'img': 'https://api.pizzahut.io/v1/content/en-in/in-1/images/pizza/margherita.90f9451fd66871fb6f9cf7d506053f18.1.jpg?width=550', 'sizeandcrust': [{'mediumPan': [{'price': 3}], 'mediumstuffedcrustcheesemax': [{'price': 5}], 'mediumstuffedcrustvegkebab': [{'price': 8}]}]}

# %%
df.to_csv("pizza_dataset.csv",index=False)

# %%
df
# Out:
#     id                             name    veg  price  \
# 0    1                       Margherita   True      3
# 1    2                  Tandoori Paneer   True      7
# 2    3                   Veggie Supreme   True      8
# 3    4            Double Paneer Supreme   True      6
# 4    4            Veggie Kebab Surprise   True      4
# 5    5                  Chicken Supreme  False      7
# 6    6            Chicken Tikka Supreme  False      6
# 7    7             Triple Chicken Feast  False      8
# 8    8                    Chicken Tikka  False      7
# 9    9           Double Chicken Sausage  False      5
# 10  10         Spiced Chicken Meatballs  False      4
# 11  11                    Double Cheese   True      3
# 12  12            Chicken Pepper Crunch  False      5
# 13  13            Italian Chicken Feast  False      6
# 14  14                    Corn & Cheese   True      5
# 15  15                   Tandoori Onion   True      6
# 16  16                Chicken Pepperoni  False      5
# 17  17           Chicken N Corn Delight  False      9
# 18  18                     Farmers Pick   True     29
# 19  19                     Classic Corn   True      5
# 20  20           Classic Onion Capsicum   True      4
# 21  21             Italian Onion Tomato   True      8
# 22  22   Tandoori Mushroom & Sweet Corn   True      5
# 23  23         Schezwan Corn & Capsicum   True      6
# 24  24                      Only Cheesy   True     40
# 25  25                  Classic Sausage  False      8
# 26  26  Classic Paneer Capsicum & Onion   True      6
# 27  27        Italian Pepperoni & Onion  False      5
# 28  28     Schezwan Meatball & Capsicum  False     10
# 29  29           Tandoori Tikka & Onion  False      5
# 30  30   Classic Loaded Chicken Delight  False      9
#
#                                           description  quantity  \
# 0                                              Cheese         1
# 1   Spiced paneeer, Onion,Green Capsicum & Red Pap...         1
# 2   Black Olives,Green Capsicum, Mushroom, Onion,R...         1
# 3   Spiced Paneer, Herbed Onion&Green Capsicum, Re...         1
# 4   Veg Kebab,Onion,Green Capsicum,Tomato & Sweet ...         1
# 5   Herbed Chicken,Schezwan Chicken Meatball,Chick...         1
# 6   Chicken Tikka,Chicken Malai Tikka,Onion,Red Pa...         1
# 7   Schezwan Chicken Meatball Herbed Chicken,Chick...         1
# 8                        Chicken Tikka, Onion, Tomato         1
# 9                                     Chicken Sausage         1
# 10                    Schezwan Chicken Meatball Onion         1
# 11                             Extra Cheese on Cheese         1
# 12  Herbed Chicken, Onion, Green Capsicum, Red Cap...         1
# 13  Herbed Chicken, Onion, Green Capsicum, Red Cap...         1
# 14                                 Cheese ,Sweet Corn         1
# 15                   Cheese & Onion in Tandoori sause         1
# 16                          Cheese ,Chicken pepperoni         1
# 17                          Cheese ,Chicken pepperoni         1
# 18  Onion Herbed & Green Capsicum, Red Capsicum, M...         1
# 19  Pizza topped with our Classic Pan sauce, sweet...         1
# 20  Pizza topped with our Classic Pan sauce, crunc...         1
# 21  Pizza topped with our Chef's Special Italian s...         1
# 22  Pizza topped with our signature tandoori sauce...         1
# 23  Pizza topped with Spicy Schezwan sauce, sweet ...         1
# 24  Pizza topped with cheesy dressing and mozzarel...         1
# 25  Pizza topped with our Classic Pan sauce, flavo...         1
# 26  Pizza topped with our Classic Pan sauce, flavo...         1
# 27  Pizza topped with our Chef's Special Italian s...         1
# 28  Pizza topped with Spicy Schezwan sauce, crunch...         1
# 29  Pizza topped with our signature tandoori sauce...         1
# 30  Pizza topped with our Classic Pan sauce, herbe...         1
#
#                                                   img  \
# 0   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 1   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 2   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 3   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 4   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 5   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 6   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 7   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 8   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 9   https://api.pizzahut.io/v1/content/en-in/in-1/...
# 10  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 11  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 12  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 13  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 14  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 15  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 16  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 17  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 18  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 19  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 20  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 21  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 22  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 23  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 24  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 25  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 26  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 27  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 28  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 29  https://api.pizzahut.io/v1/content/en-in/in-1/...
# 30  https://api.pizzahut.io/v1/content/en-in/in-1/...
#
#                                          sizeandcrust
# 0   [{'mediumPan': [{'price': 3}], 'mediumstuffedc...
# 1   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 2   [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 3   [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 4   [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 5   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 6   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 7   [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 8   [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 9   [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 10  [{'mediumPan': [{'price': 4}], 'mediumstuffedc...
# 11  [{'mediumPan': [{'price': 3}], 'mediumstuffedc...
# 12  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 13  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 14  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 15  [{'mediumPan': [{'price': 7}], 'mediumstuffedc...
# 16  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 17  [{'mediumPan': [{'price': 9}], 'mediumstuffedc...
# 18  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 19  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 20  [{'mediumPan': [{'price': 4}], 'mediumstuffedc...
# 21  [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 22  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 23  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 24  [{'mediumPan': [{'price': 40}], 'mediumstuffed...
# 25  [{'mediumPan': [{'price': 8}], 'mediumstuffedc...
# 26  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 27  [{'mediumPan': [{'price': 5}], 'mediumstuffedc...
# 28  [{'mediumPan': [{'price': 12}], 'mediumstuffed...
# 29  [{'mediumPan': [{'price': 6}], 'mediumstuffedc...
# 30  [{'mediumPan': [{'price': 9}], 'mediumstuffedc...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\DELL
